# %% [markdown]
# <a href="https://colab.research.google.com/github/rishike/llm_from_scratch/blob/main/byte_pair_encoding.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
pip install tiktoken

# %%
import importlib

# %%
import tiktoken

# %%
print(importlib.metadata.version("tiktoken"))
# Out:
# 0.12.0

# %%
tokenizer = tiktoken.get_encoding("gpt2")

# %%
tokenizer
# Out:
# <Encoding 'gpt2'>

# %%
text = (
    "hello, do you like tea? <|endoftext|> In the sunlit terraces"
    "of someunknownPlace."
)

# %%
integers = tokenizer.encode(text, allowed_special={"<|endoftext|>"})
integers
# Out:
# [31373,
#  11,
#  466,
#  345,
#  588,
#  8887,
#  30,
#  220,
#  50256,
#  554,
#  262,
#  4252,
#  18250,
#  8812,
#  2114,
#  1659,
#  617,
#  34680,
#  27271,
#  13]

# %%
strings = tokenizer.decode(integers)
strings
# Out:
# 'hello, do you like tea? <|endoftext|> In the sunlit terracesof someunknownPlace.'

# %%
integers = tokenizer.encode("AKwirw ier")
integers
# Out:
# [10206, 86, 343, 86, 220, 959]

# %%
tokenizer.decode(integers)
# Out:
# 'AKwirw ier'
